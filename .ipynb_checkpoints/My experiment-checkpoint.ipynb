# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv("C:/Users/ashuk/Desktop/kaggle/housingpriceregression/data/train.csv")

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
cors = train_df.corr()

# %%
cors.values
# Out:
# array([[ 1.00000000e+00,  1.11564782e-02, -1.06006886e-02, ...,
#          2.11721766e-02,  7.11794017e-04, -2.19167194e-02],
#        [ 1.11564782e-02,  1.00000000e+00, -3.86346885e-01, ...,
#         -1.35846432e-02, -2.14070379e-02, -8.42841351e-02],
#        [-1.06006886e-02, -3.86346885e-01,  1.00000000e+00, ...,
#          1.11999548e-02,  7.44958921e-03,  3.51799097e-01],
#        ...,
#        [ 2.11721766e-02, -1.35846432e-02,  1.11999548e-02, ...,
#          1.00000000e+00, -1.45721413e-01,  4.64322452e-02],
#        [ 7.11794017e-04, -2.14070379e-02,  7.44958921e-03, ...,
#         -1.45721413e-01,  1.00000000e+00, -2.89225852e-02],
#        [-2.19167194e-02, -8.42841351e-02,  3.51799097e-01, ...,
#          4.64322452e-02, -2.89225852e-02,  1.00000000e+00]])

# %%
f, ax = plt.subplots(figsize=(40,40))
sns.heatmap(cors, annot=True, square=True)

# %%
y_train = train_df["SalePrice"]

# %%
x_train = train_df[["OverallQual","TotalBsmtSF","GrLivArea","GarageCars","GarageArea"]]

# %%
x_train
# Out:
#       OverallQual  TotalBsmtSF  GrLivArea  GarageCars  GarageArea
# 0               7          856       1710           2         548
# 1               6         1262       1262           2         460
# 2               7          920       1786           2         608
# 3               7          756       1717           3         642
# 4               8         1145       2198           3         836
# ...           ...          ...        ...         ...         ...
# 1455            6          953       1647           2         460
# 1456            6         1542       2073           2         500
# 1457            7         1152       2340           1         252
# 1458            5         1078       1078           1         240
# 1459            5         1256       1256           1         276
#
# [1460 rows x 5 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regr = RandomForestRegressor()

# %%
regr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
test_df = pd.read_csv("../data/test.csv")

# %%
test_df = test_df[["OverallQual","TotalBsmtSF","GrLivArea","GarageCars","GarageArea"]]

# %%
test_df.isna().sum()
# Out:
# OverallQual    0
# TotalBsmtSF    1
# GrLivArea      0
# GarageCars     1
# GarageArea     1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer()

# %%
test_df = imputer.fit_transform(test_df.values)

# %%
y_pred = regr.predict(test_df)

# %%
y_pred
# Out:
# array([127279.33333333, 158219.44      , 147253.58      , ...,
#        151552.74      , 102836.31666667, 233060.58      ])

# %%
len(y_pred)
# Out:
# 1459

# %%
len(test_df)
# Out:
# 1459

# %%
sub = pd.read_csv("../data/sample_submission.csv")

# %%
sub = sub[["Id"]]

# %%
sub["SalePrice"] = y_pred

# %%
sub.to_csv("../data/my_submission2.csv", index=False)

# %%
sub = sub[["Id","SalePrice"]]

# %%
sub.columns
# Out:
# Index(['Id', 'SalePrice'], dtype='object')

# %%
sub
# Out:
#         Id      SalePrice
# 0     1461  127279.333333
# 1     1462  158219.440000
# 2     1463  147253.580000
# 3     1464  180930.000000
# 4     1465  227279.120000
# ...    ...            ...
# 1454  2915   72341.000000
# 1455  2916   82309.654762
# 1456  2917  151552.740000
# 1457  2918  102836.316667
# 1458  2919  233060.580000
#
# [1459 rows x 2 columns]

# %%
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-0.90.tar.gz (676 kB)
# ERROR: Files/directories not found in C:\Users\ashuk\AppData\Local\Temp\pip-install-iiza6sna\xgboost\pip-egg-info

# %%
x_train = train_df[["OverallQual","TotalBsmtSF","GrLivArea"]]

# %%
test_df = test_df[["OverallQual","TotalBsmtSF","GrLivArea"]]

# %%
test_df.isna().sum()
# Out:
# OverallQual    0
# TotalBsmtSF    1
# GrLivArea      0
# dtype: int64

# %%
regr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_pred = regr.predict(test_df)

# %%
len(y_pred)
# Out:
# 1459
